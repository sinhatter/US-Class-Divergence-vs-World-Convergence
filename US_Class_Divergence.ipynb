# %% [markdown]
# <a href="https://colab.research.google.com/github/sinhatter/US-Class-Divergence-vs-World-Convergence/blob/Divergence/US_Class_Divergence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# %%
url = 'https://raw.githubusercontent.com/sinhatter/US-Class-Divergence-vs-World-Convergence/Divergence/Percentage_Income_Quintiles.csv'
df = pd.read_csv(url)

# %%
df=df.drop(0)
df=df.drop(1)
df=df.drop(2)
df=df.drop(3)
df=df.drop(4)
df=df.drop(5)
df=df.drop(6)
df.drop('Unnamed: 1', inplace=True, axis=1)

# %%
df.columns = ['Year', 'Lowest Fifth', 'Second Fifth', 'Third Fifth', 'Fourth Fifth', 'Highest Fifth', 'Top 5 Percent']

# %%
for i in df.iloc[:,0]:
  b=i
  a=b.find("(")
  if(a!=-1):
    b=b[0:a]
  df=df.replace(i,b)

df=df.drop(10)
df=df.drop(15)
df
# Out:
#      Year Lowest Fifth Second Fifth Third Fifth Fourth Fifth Highest Fifth  \
# 7    2020          3.0          8.1        14.0         22.6          52.2
# 8    2019          3.1          8.3        14.1         22.7          51.9
# 9    2018          3.1          8.3        14.1         22.6          52.0
# 11   2017          3.1          8.2        14.3         23.0          51.5
# 12   2016          3.1          8.3        14.2         22.9          51.5
# 13   2015          3.1          8.2        14.3         23.2          51.1
# 14   2014          3.1          8.2        14.3         23.2          51.2
# 16  2013           3.2          8.4        14.4         23.0          51.0
# 17   2012          3.2          8.3        14.4         23.0          51.0
# 18   2011          3.2          8.4        14.3         23.0          51.1
# 19  2010           3.3          8.5        14.6         23.4          50.3
# ...

# %%
url1 = 'https://raw.githubusercontent.com/sinhatter/US-Class-Divergence-vs-World-Convergence/Divergence/UpperLimitofQuintile.csv'
df1 = pd.read_csv(url1)

# %%
for i in range(0,8):
  df1=df1.drop(i)

for i in range(64,123):
  df1=df1.drop(i)

for i in df1.iloc[:,0]:
  b=i
  a=b.find("(")
  if(a!=-1):
    b=b[0:a]
  df1=df1.replace(i,b)

df1.drop('Unnamed: 1', inplace=True, axis=1)
df1.columns = ['Year', 'Lowest Fifth', 'Second Fifth', 'Third Fifth', 'Fourth Fifth', 'Top 5 Percent']

df1=df1.drop(11)
df1=df1.drop(16)
df1
# Out:
#      Year Lowest Fifth Second Fifth Third Fifth Fourth Fifth Top 5 Percent
# 8    2020       27,026       52,179      85,076      141,110       273,739
# 9    2019       28,084       53,503      86,488      142,501       270,002
# 10   2018       25,600       50,000      79,542      130,000       248,728
# 12   2017       24,638       47,110      77,552      126,855       237,034
# 13   2016       24,002       45,600      74,869      121,018       225,251
# 14   2015       22,800       43,511      72,001      117,002       214,462
# 15   2014       21,432       41,186      68,212      112,262       206,568
# 17  2013        20,900       40,187      65,501      105,910       196,000
# 18   2012       20,599       39,764      64,582      104,096       191,156
# 19   2011       20,262       38,520      62,434      101,582       186,000
# 20  2010        20,000       38,000      61,500      100,029       180,485
# ...

# %%
import matplotlib.pyplot as plt

y1=list()
y2=list()
y3=list()
y4=list()
y5=list()
y6=list()
x=[]



for i in range(62,15,-1):
  x.append(df.loc[i].iat[0])
  y1.append(df.loc[i].iat[1])
  y2.append(df.loc[i].iat[2])
  y3.append(df.loc[i].iat[3])
  y4.append(df.loc[i].iat[4])
  y5.append(df.loc[i].iat[5])
  y6.append(df.loc[i].iat[6])

for i in range(14,10,-1):
  x.append(df.loc[i].iat[0])
  y1.append(df.loc[i].iat[1])
  y2.append(df.loc[i].iat[2])
  y3.append(df.loc[i].iat[3])
  y4.append(df.loc[i].iat[4])
  y5.append(df.loc[i].iat[5])
  y6.append(df.loc[i].iat[6])

for i in range(9,6,-1):
  x.append(df.loc[i].iat[0])
  y1.append(df.loc[i].iat[1])
  y2.append(df.loc[i].iat[2])
  y3.append(df.loc[i].iat[3])
  y4.append(df.loc[i].iat[4])
  y5.append(df.loc[i].iat[5])
  y6.append(df.loc[i].iat[6])

  
y21=list()
y22=list()
y23=list()
y24=list()
y25=list()
x2=[]

for i in range (63,16,-1):
  x2.append(df1.loc[i].iat[0])
  y21.append(df1.loc[i].iat[1])
  y22.append(df1.loc[i].iat[2])
  y23.append(df1.loc[i].iat[3])
  y24.append(df1.loc[i].iat[4])
  y25.append(df1.loc[i].iat[5])

for i in range(15,11,-1):
  x2.append(df1.loc[i].iat[0])
  y21.append(df1.loc[i].iat[1])
  y22.append(df1.loc[i].iat[2])
  y23.append(df1.loc[i].iat[3])
  y24.append(df1.loc[i].iat[4])
  y25.append(df1.loc[i].iat[5])


for i in range(10,7 ,-1):
  x2.append(df1.loc[i].iat[0])
  y21.append(df1.loc[i].iat[1])
  y22.append(df1.loc[i].iat[2])
  y23.append(df1.loc[i].iat[3])
  y24.append(df1.loc[i].iat[4])
  y25.append(df1.loc[i].iat[5])

# %% [markdown]
# import numpy as np
#
# plt.style.use('fivethirtyeight')
# fig = plt.figure(figsize=(10,3))
#
# plt1 = fig.add_subplot(231)
# plt2 = fig.add_subplot(232)
# plt3 = fig.add_subplot(233)
# plt4 = fig.add_subplot(234)
# plt5 = fig.add_subplot(235)
# plt6 = fig.add_subplot(236)
#
# plt1.plot(x, y1, color ='r')
# plt1.set_title('lowest fifth')
#
# plt2.plot(x, y2, color ='b')
# plt2.set_title('second fifth')
#
# plt3.plot(x, y3, color ='g')
# plt3.set_title('third fifth')
#
# plt4.plot(x, y4, color ='k')
# plt4.set_title('fourth fifth')
#
# plt5.plot(x, y5, color ='b')
# plt5.set_title('last fifth')
#
# plt6.plot(x, y6, color ='y')
# plt6.set_title('top five percent')
#
#
#
#
# plt1.set_xticks(np.arange(1967, len(x)+1968, 10))
# plt1.set_yticks(np.arange(0, max(y1), .1))
#
# plt2.set_xticks(np.arange(1967, len(x)+1968, 10))
# plt2.set_yticks(np.arange(0, max(y2), 10))
#
# plt3.set_xticks(np.arange(1967, len(x)+1968, 10))
# plt3.set_yticks(np.arange(0, max(y3), 10))
#
# plt4.set_xticks(np.arange(1967, len(x)+1968, 10))
# plt4.set_yticks(np.arange(0, max(y4), 10))
#
# plt5.set_xticks(np.arange(1967, len(x)+1968, 10))
# plt5.set_yticks(np.arange(0, max(y5), 10))
#
# plt6.set_xticks(np.arange(1967, len(x)+1968, 10))
# plt6.set_yticks(np.arange(0, max(y6), 10))
#
# plt.show()

# %%
plt.plot(x,y1)

plt.gca().invert_yaxis()


plt.xlabel("Year")
plt.ylabel("Percent of Total Income")
plt.title("Income Percentage for Lowest Fifth of Familes")

plt.rcParams["figure.figsize"] = (50,10)


plt.show()

# %%
plt.plot(x,y2)

plt.gca().invert_yaxis()


plt.xlabel("Year")
plt.ylabel("Percent of Total Income")
plt.title("Income Percentage for Second Fifth of Familes")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x,y3)

plt.gca().invert_yaxis()


plt.xlabel("Year")
plt.ylabel("Percent of Total Income")
plt.title("Income Percentage for Third Fifth of Familes")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x,y4)

plt.gca().invert_yaxis()


plt.xlabel("Year")
plt.ylabel("Percent of Total Income")
plt.title("Income Percentage for Fourth Fifth of Familes")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x,y5)



plt.xlabel("Year")
plt.ylabel("Percent of Total Income")
plt.title("Income Percentage for Highest Fifth of Familes")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x,y6)




plt.xlabel("Year")
plt.ylabel("Percent of Total Income")
plt.title("Income Percentage for Top 5 Percent of Familes")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x2,y21)




plt.xlabel("Year")
plt.ylabel("Total Income")
plt.title("Income for Lowest 20 Pecent of Families")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x2,y22)




plt.xlabel("Year")
plt.ylabel("Total Income")
plt.title("Income for Second 20 Pecent of Families")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x2,y23)




plt.xlabel("Year")
plt.ylabel("Total Income")
plt.title("Income for Third 20 Pecent of Families")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x2,y24)




plt.xlabel("Year")
plt.ylabel("Total Income")
plt.title("Income for Fourth 20 Pecent of Families")

plt.rcParams["figure.figsize"] = (50,20)

plt.show()

# %%
plt.plot(x2,y25)




plt.xlabel("Year")
plt.ylabel("Total Income")
plt.title("Income for Highest 20 Pecent of Families")

plt.rcParams["figure.figsize"] = (60,25)

plt.show()

# %%
y1_change= 0.0
y2_change= 0.0
y3_change= 0.0
y4_change= 0.0
y5_change= 0.0
y6_change= 0.0



for i in range(62,16,-1):
  y1_change+=(float(df.loc[i-1].iat[1])/float(df.loc[i].iat[1]))*100-100
  y2_change+=(float(df.loc[i-1].iat[2])/float(df.loc[i].iat[2]))*100-100
  y3_change+=(float(df.loc[i-1].iat[3])/float(df.loc[i].iat[3]))*100-100
  y4_change+=(float(df.loc[i-1].iat[4])/float(df.loc[i].iat[4]))*100-100
  y5_change+=(float(df.loc[i-1].iat[5])/float(df.loc[i].iat[5]))*100-100
  y6_change+=(float(df.loc[i-1].iat[6])/float(df.loc[i].iat[6]))*100-100
  
y1_change+=(float(df.loc[14].iat[1])/float(df.loc[16].iat[1]))*100-100
y2_change+=(float(df.loc[14].iat[2])/float(df.loc[16].iat[2]))*100-100
y3_change+=(float(df.loc[14].iat[3])/float(df.loc[16].iat[3]))*100-100
y4_change+=(float(df.loc[14].iat[4])/float(df.loc[16].iat[4]))*100-100
y5_change+=(float(df.loc[14].iat[5])/float(df.loc[16].iat[5]))*100-100
y6_change+=(float(df.loc[14].iat[6])/float(df.loc[16].iat[6]))*100-100

for i in range(14,11,-1):
  y1_change+=(float(df.loc[i-1].iat[1])/float(df.loc[i].iat[1]))*100-100
  y2_change+=(float(df.loc[i-1].iat[2])/float(df.loc[i].iat[2]))*100-100
  y3_change+=(float(df.loc[i-1].iat[3])/float(df.loc[i].iat[3]))*100-100
  y4_change+=(float(df.loc[i-1].iat[4])/float(df.loc[i].iat[4]))*100-100
  y5_change+=(float(df.loc[i-1].iat[5])/float(df.loc[i].iat[5]))*100-100
  y6_change+=(float(df.loc[i-1].iat[6])/float(df.loc[i].iat[6]))*100-100

y1_change+=(float(df.loc[9].iat[1])/float(df.loc[11].iat[1]))*100-100
y2_change+=(float(df.loc[9].iat[2])/float(df.loc[11].iat[2]))*100-100
y3_change+=(float(df.loc[9].iat[3])/float(df.loc[11].iat[3]))*100-100
y4_change+=(float(df.loc[9].iat[4])/float(df.loc[11].iat[4]))*100-100
y5_change+=(float(df.loc[9].iat[5])/float(df.loc[11].iat[5]))*100-100
y6_change+=(float(df.loc[9].iat[6])/float(df.loc[11].iat[6]))*100-100

for i in range(9,7,-1):
  y1_change+=(float(df.loc[i-1].iat[1])/float(df.loc[i].iat[1]))*100-100
  y2_change+=(float(df.loc[i-1].iat[2])/float(df.loc[i].iat[2]))*100-100
  y3_change+=(float(df.loc[i-1].iat[3])/float(df.loc[i].iat[3]))*100-100
  y4_change+=(float(df.loc[i-1].iat[4])/float(df.loc[i].iat[4]))*100-100
  y5_change+=(float(df.loc[i-1].iat[5])/float(df.loc[i].iat[5]))*100-100
  y6_change+=(float(df.loc[i-1].iat[6])/float(df.loc[i].iat[6]))*100-100

y1_avg_change= y1_change/53
y2_avg_change= y2_change/53
y3_avg_change= y3_change/53
y4_avg_change= y4_change/53
y5_avg_change= y5_change/53
y6_avg_change= y6_change/53

# %%
y21_change= 0.0
y22_change= 0.0
y23_change= 0.0
y24_change= 0.0
y25_change= 0.0


def findInt( a):
  b=a
  if b.find(",")!=-1:
    c=b.find(",")

  b=a[0:c:1]+b[c+1::]
  return int(b)



for i in range (63,17,-1):


  y21_change+=(findInt(df1.loc[i-1].iat[1])/findInt(df1.loc[i].iat[1]))*100-100
  y22_change+=(findInt(df1.loc[i-1].iat[2])/findInt(df1.loc[i].iat[2]))*100-100
  y23_change+=(findInt(df1.loc[i-1].iat[3])/findInt(df1.loc[i].iat[3]))*100-100
  y24_change+=(findInt(df1.loc[i-1].iat[4])/findInt(df1.loc[i].iat[4]))*100-100
  y25_change+=(findInt(df1.loc[i-1].iat[5])/findInt(df1.loc[i].iat[5]))*100-100

y21_change+=(findInt(df1.loc[15].iat[1])/findInt(df1.loc[17].iat[1]))*100-100
y22_change+=(findInt(df1.loc[15].iat[2])/findInt(df1.loc[17].iat[2]))*100-100
y23_change+=(findInt(df1.loc[15].iat[3])/findInt(df1.loc[17].iat[3]))*100-100
y24_change+=(findInt(df1.loc[15].iat[4])/findInt(df1.loc[17].iat[4]))*100-100
y25_change+=(findInt(df1.loc[15].iat[5])/findInt(df1.loc[17].iat[5]))*100-100
  
for i in range(15,12,-1):
  y21_change+=(findInt(df1.loc[i-1].iat[1])/findInt(df1.loc[i].iat[1]))*100-100
  y22_change+=(findInt(df1.loc[i-1].iat[2])/findInt(df1.loc[i].iat[2]))*100-100
  y23_change+=(findInt(df1.loc[i-1].iat[3])/findInt(df1.loc[i].iat[3]))*100-100
  y24_change+=(findInt(df1.loc[i-1].iat[4])/findInt(df1.loc[i].iat[4]))*100-100
  y25_change+=(findInt(df1.loc[i-1].iat[5])/findInt(df1.loc[i].iat[5]))*100-100

y21_change+=(findInt(df1.loc[10].iat[1])/findInt(df1.loc[12].iat[1]))*100-100
y22_change+=(findInt(df1.loc[10].iat[2])/findInt(df1.loc[12].iat[2]))*100-100
y23_change+=(findInt(df1.loc[10].iat[3])/findInt(df1.loc[12].iat[3]))*100-100
y24_change+=(findInt(df1.loc[10].iat[4])/findInt(df1.loc[12].iat[4]))*100-100
y25_change+=(findInt(df1.loc[10].iat[5])/findInt(df1.loc[12].iat[5]))*100-100 

for i in range(10,8 ,-1):
  y21_change+=(findInt(df1.loc[i-1].iat[1])/findInt(df1.loc[i].iat[1]))*100-100
  y22_change+=(findInt(df1.loc[i-1].iat[2])/findInt(df1.loc[i].iat[2]))*100-100
  y23_change+=(findInt(df1.loc[i-1].iat[3])/findInt(df1.loc[i].iat[3]))*100-100
  y24_change+=(findInt(df1.loc[i-1].iat[4])/findInt(df1.loc[i].iat[4]))*100-100
  y25_change+=(findInt(df1.loc[i-1].iat[5])/findInt(df1.loc[i].iat[5]))*100-100

y21_avg_change= y21_change/53
y22_avg_change= y22_change/53
y23_avg_change= y23_change/53
y24_avg_change= y24_change/53
y25_avg_change= y25_change/53
